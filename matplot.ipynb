# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#object oriented method
fig = plt.figure() #imaginary blank canvas

axes = fig.add_axes([0.1,0.1,0.8,0.8])
# left bottom, width and height

axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)

axes2.plot(y,x,'r')

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

plt.tight_layout() # to remove over lapping of numbers

axes[0].plot(x,y)
axes[1].plot(y,x,'b')

# %%
#dpi - dots per inch
fig,axes = plt.subplots()

axes.plot(x,x**2, label='x square')
axes.plot(x,x**3, label='x cube')

axes.legend(loc = 0)

# %%
#fig.savefig('mypic.png')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple', linewidth=2,alpha=1, linestyle='-.', marker = '*' ,ms = '13', markerfacecolor = 'yellow', markeredgecolor='green') # alpha is for opacity ms = markersize
# . , - , -. , steps, : , ; , , ,

# %%
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])
